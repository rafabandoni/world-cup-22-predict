# %%
import pandas as pd

# %%
data = pd.read_csv('data/all_matches_data.csv')
data.head()
# Out:
#    match_id        league       match_date       team_1  score_1   team_2  \
# 0       1.0  Europe: Euro  6/12/2004 16:00     Portugal      1.0   Greece
# 1       2.0  Europe: Euro  6/12/2004 18:45        Spain      1.0   Russia
# 2       3.0  Europe: Euro  6/13/2004 16:00  Switzerland      0.0  Croatia
# 3       4.0  Europe: Euro  6/13/2004 18:45       France      2.0  England
# 4       5.0  Europe: Euro  6/14/2004 16:00      Denmark      0.0    Italy
#
#    score_2 note  avg_odds_win_1  avg_odds_draw  avg_odds_win_2
# 0      2.0  NaN            1.52           3.54            6.58
# 1      0.0  NaN            1.64           3.43            5.28
# 2      0.0  NaN            3.04           3.17            2.22
# 3      1.0  NaN            1.99           3.21            3.52
# 4      0.0  NaN            4.90           3.27            1.70

# %%
# map teams
map_country = pd.DataFrame(data['team_1'].unique()).reset_index(drop=False).rename(columns={'index' : 'code', 0 : 'country'})
map_country.head()
# Out:
#    code      country
# 0     0     Portugal
# 1     1        Spain
# 2     2  Switzerland
# 3     3       France
# 4     4      Denmark
